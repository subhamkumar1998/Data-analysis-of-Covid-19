# %% [markdown]
# # COVID-19 SMALL DATASET

# %% [markdown]
# We have taken a small dataset of covid-19, just for your understanding purpose. You have to work on the original dataset which contains about 15000 rows

# %% [markdown]
# The data used here is till 02-August-2021

# %% [markdown]
# This data is available as a CSV file , download from kaggle.

# %% [markdown]
# We will analyze this data using the Pandas DataFrame.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("new corona case file.csv")
df
# Out:
#            Date  State      Country/Region  Confirmed  Deaths  Recovered  \
# 0    20-12-2020    NaN         Afghanistan      36263    1269      25198
# 1    21-12-2020    NaN             Albania       4880     144       2745
# 2    22-12-2020    NaN             Algeria      27973    1163      18837
# 3    23-12-2020    NaN             Andorra        907      52        803
# 4    24-12-2020    NaN              Angola        950      41        242
# ..          ...    ...                 ...        ...     ...        ...
# 182  29-07-2021    NaN  West Bank and Gaza      10621      78       3752
# 183  30-07-2021    NaN      Western Sahara         10       1          8
# 184  31-07-2021    NaN               Yemen       1691     483        833
# 185  01-08-2021    NaN              Zambia       4552     140       2815
# 186  02-08-2021    NaN            Zimbabwe       2704      36        542
#
#      Active  New cases  New deaths  New recovered
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            187 non-null    object
#  1   State           0 non-null      float64
#  2   Country/Region  187 non-null    object
#  3   Confirmed       187 non-null    int64
#  4   Deaths          187 non-null    int64
#  5   Recovered       187 non-null    int64
#  6   Active          187 non-null    int64
#  7   New cases       187 non-null    int64
#  8   New deaths      187 non-null    int64
#  9   New recovered   187 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 14.7+ KB

# %%
df.describe()
# Out:
#        State     Confirmed         Deaths     Recovered        Active  \
# count    0.0  1.870000e+02     187.000000  1.870000e+02  1.870000e+02
# mean     NaN  8.813094e+04    3497.518717  5.063148e+04  3.400194e+04
# std      NaN  3.833187e+05   14100.002482  1.901882e+05  2.133262e+05
# min      NaN  1.000000e+01       0.000000  0.000000e+00  0.000000e+00
# 25%      NaN  1.114000e+03      18.500000  6.265000e+02  1.415000e+02
# 50%      NaN  5.059000e+03     108.000000  2.815000e+03  1.600000e+03
# 75%      NaN  4.046050e+04     734.000000  2.260600e+04  9.149000e+03
# max      NaN  4.290259e+06  148011.000000  1.846641e+06  2.816444e+06
#
#           New cases   New deaths  New recovered
# count    187.000000   187.000000     187.000000
# mean    1222.957219    28.957219     933.812834
# std     5710.374790   120.037173    4197.719635
# min        0.000000     0.000000       0.000000
# 25%        4.000000     0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# State             187
# Country/Region      0
# Confirmed           0
# Deaths              0
# Recovered           0
# Active              0
# New cases           0
# New deaths          0
# New recovered       0
# dtype: int64

# %%
# let us plot a heatmap of the missing values

# import the required libraries
# import the library seaborn and matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# figsize: set the plot size
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Show the number of confirmed , recovered , Death cases, new deaths in each region

# %%
df.groupby("Country/Region").sum().head(5)
# Out:
#                 State  Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan       0.0      36263    1269      25198    9796        106
# Albania           0.0       4880     144       2745    1991        117
# Algeria           0.0      27973    1163      18837    7973        616
# Andorra           0.0        907      52        803      52         10
# Angola            0.0        950      41        242     667         18
#
#                 New deaths  New recovered
# Country/Region
# Afghanistan             10             18
# Albania                  6             63
# Algeria                  8            749
# Andorra                  0              0
# Angola                   1              0

# %%
df.groupby("Country/Region")['Confirmed'].sum().head(10)
# Out:
# Country/Region
# Afghanistan             36263
# Albania                  4880
# Algeria                 27973
# Andorra                   907
# Angola                    950
# Antigua and Barbuda        86
# Argentina              167416
# Armenia                 37390
# Australia               15303
# Austria                 20558
# Name: Confirmed, dtype: int64

# %%
df.groupby("Country/Region")['Confirmed'].sum().head(11).sort_values(ascending= True)
# Out:
# Country/Region
# Antigua and Barbuda        86
# Andorra                   907
# Angola                    950
# Albania                  4880
# Australia               15303
# Austria                 20558
# Algeria                 27973
# Azerbaijan              30446
# Afghanistan             36263
# Armenia                 37390
# Argentina              167416
# Name: Confirmed, dtype: int64

# %%
df.groupby("Country/Region")['Recovered'].sum().head(11).sort_values(ascending= True)
# Out:
# Country/Region
# Antigua and Barbuda       65
# Angola                   242
# Andorra                  803
# Albania                 2745
# Australia               9311
# Austria                18246
# Algeria                18837
# Azerbaijan             23242
# Afghanistan            25198
# Armenia                26665
# Argentina              72575
# Name: Recovered, dtype: int64

# %%
df.groupby("Country/Region")["Deaths","New deaths"].sum().head(8)
# Out:
# C:\Users\SUBHAM~1\AppData\Local\Temp/ipykernel_24072/199130432.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Country/Region")["Deaths","New deaths"].sum().head(8)
#                      Deaths  New deaths
# Country/Region
# Afghanistan            1269          10
# Albania                 144           6
# Algeria                1163           8
# Andorra                  52           0
# Angola                   41           1
# Antigua and Barbuda       3           0
# Argentina              3059         120
# Armenia                 711           6

# %% [markdown]
# # Graph to plot Most Active Cases

# %%
top10ActiveCases=df.groupby(by='Country/Region').max()[['Active','Date']].sort_values(by=['Active'],ascending=False).reset_index()

# %%
fig=plt.figure(figsize=(16,10))
plt.title("Top 10 country with most Active Cases",size=22)
ax=sns.barplot(data=top10ActiveCases.iloc[:10],y='Active',x='Country/Region',linewidth=2,edgecolor='black')
plt.xlabel("Country")
plt.ylabel("Total Active Cases")
plt.show()

# %% [markdown]
# # To plot highest Number of Death

# %%
# top states with highest number of deaths
top10Deaths= df.groupby(by='Country/Region').max()[['Deaths','Date']].sort_values(by=['Deaths'],ascending=False).reset_index()

# %%
fig=plt.figure(figsize=(16,10))
plt.title("Top 10 country with most Deaths",size=22)
ax=sns.barplot(data=top10Deaths.iloc[:10],y='Deaths',x='Country/Region',linewidth=2,edgecolor='black')
plt.xlabel("Country/Region")
plt.ylabel("Total Deaths")
plt.show()

# %%
# Remove all the cases where confirmed cases less then 1000?

# %%
df.head(2)
# Out:
#          Date  State Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0  20-12-2020    NaN    Afghanistan      36263    1269      25198    9796
# 1  21-12-2020    NaN        Albania       4880     144       2745    1991
#
#    New cases  New deaths  New recovered
# 0        106          10             18
# 1        117           6             63

# %%
df[df. Confirmed<1000]
df.head(20)
# Out:
#           Date  State       Country/Region  Confirmed  Deaths  Recovered  \
# 0   20-12-2020    NaN          Afghanistan      36263    1269      25198
# 1   21-12-2020    NaN              Albania       4880     144       2745
# 2   22-12-2020    NaN              Algeria      27973    1163      18837
# 3   23-12-2020    NaN              Andorra        907      52        803
# 4   24-12-2020    NaN               Angola        950      41        242
# 5   25-12-2020    NaN  Antigua and Barbuda         86       3         65
# 6   26-12-2020    NaN            Argentina     167416    3059      72575
# 7   27-12-2020    NaN              Armenia      37390     711      26665
# 8   28-12-2020    NaN            Australia      15303     167       9311
# 9   29-12-2020    NaN              Austria      20558     713      18246
# 10  30-12-2020    NaN           Azerbaijan      30446     423      23242
# 11  31-12-2020    NaN              Bahamas        382      11         91
# ...

# %%
#to remove the record  satisfy a particular condition
df = df[~(df.Confirmed < 1000)]

# %%
df.head(20)
# Out:
#           Date  State          Country/Region  Confirmed  Deaths  Recovered  \
# 0   20-12-2020    NaN             Afghanistan      36263    1269      25198
# 1   21-12-2020    NaN                 Albania       4880     144       2745
# 2   22-12-2020    NaN                 Algeria      27973    1163      18837
# 6   26-12-2020    NaN               Argentina     167416    3059      72575
# 7   27-12-2020    NaN                 Armenia      37390     711      26665
# 8   28-12-2020    NaN               Australia      15303     167       9311
# 9   29-12-2020    NaN                 Austria      20558     713      18246
# 10  30-12-2020    NaN              Azerbaijan      30446     423      23242
# 12  01-01-2021    NaN                 Bahrain      39482     141      36110
# 13  02-01-2021    NaN              Bangladesh     226225    2965     125683
# 15  04-01-2021    NaN                 Belarus      67251     538      60492
# ...

# %%
# In which region , maximum number of confirmed cases were recorded ?

# %%
df1=pd.read_csv("new corona case file.csv")

# %%
df1
# Out:
#            Date  State      Country/Region  Confirmed  Deaths  Recovered  \
# 0    20-12-2020    NaN         Afghanistan      36263    1269      25198
# 1    21-12-2020    NaN             Albania       4880     144       2745
# 2    22-12-2020    NaN             Algeria      27973    1163      18837
# 3    23-12-2020    NaN             Andorra        907      52        803
# 4    24-12-2020    NaN              Angola        950      41        242
# ..          ...    ...                 ...        ...     ...        ...
# 182  29-07-2021    NaN  West Bank and Gaza      10621      78       3752
# 183  30-07-2021    NaN      Western Sahara         10       1          8
# 184  31-07-2021    NaN               Yemen       1691     483        833
# 185  01-08-2021    NaN              Zambia       4552     140       2815
# 186  02-08-2021    NaN            Zimbabwe       2704      36        542
#
#      Active  New cases  New deaths  New recovered
# ...

# %%
df1.groupby("Country/Region").Confirmed.sum().sort_values(ascending = False).head(15)
# Out:
# Country/Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Name: Confirmed, dtype: int64

# %%
# In which region , minimum number of Deaths cases were recorded ?

# %%
df1.groupby("Country/Region").Deaths.sum().sort_values(ascending = True)
# Out:
# Country/Region
# Fiji                   0
# Holy See               0
# Grenada                0
# Laos                   0
# Greenland              0
#                    ...
# Italy              35112
# Mexico             44022
# United Kingdom     45844
# Brazil             87618
# US                148011
# Name: Deaths, Length: 187, dtype: int64

# %%
#How many Deaths , COnfirmed and Active cases reported from India til 17 april 2021?

# %%
df2= pd.read_csv("new corona case file.csv")

# %%
df2.head(20)
# Out:
#           Date  State       Country/Region  Confirmed  Deaths  Recovered  \
# 0   20-12-2020    NaN          Afghanistan      36263    1269      25198
# 1   21-12-2020    NaN              Albania       4880     144       2745
# 2   22-12-2020    NaN              Algeria      27973    1163      18837
# 3   23-12-2020    NaN              Andorra        907      52        803
# 4   24-12-2020    NaN               Angola        950      41        242
# 5   25-12-2020    NaN  Antigua and Barbuda         86       3         65
# 6   26-12-2020    NaN            Argentina     167416    3059      72575
# 7   27-12-2020    NaN              Armenia      37390     711      26665
# 8   28-12-2020    NaN            Australia      15303     167       9311
# 9   29-12-2020    NaN              Austria      20558     713      18246
# 10  30-12-2020    NaN           Azerbaijan      30446     423      23242
# 11  31-12-2020    NaN              Bahamas        382      11         91
# ...

# %%
#changing the name of  Country/Region to "country"
df2 =df2.rename(columns={"Country/Region": "Country"})
df2
# Out:
#            Date  State             Country  Confirmed  Deaths  Recovered  \
# 0    20-12-2020    NaN         Afghanistan      36263    1269      25198
# 1    21-12-2020    NaN             Albania       4880     144       2745
# 2    22-12-2020    NaN             Algeria      27973    1163      18837
# 3    23-12-2020    NaN             Andorra        907      52        803
# 4    24-12-2020    NaN              Angola        950      41        242
# ..          ...    ...                 ...        ...     ...        ...
# 182  29-07-2021    NaN  West Bank and Gaza      10621      78       3752
# 183  30-07-2021    NaN      Western Sahara         10       1          8
# 184  31-07-2021    NaN               Yemen       1691     483        833
# 185  01-08-2021    NaN              Zambia       4552     140       2815
# 186  02-08-2021    NaN            Zimbabwe       2704      36        542
#
#      Active  New cases  New deaths  New recovered
# ...

# %%
df2[df2.Country == "India"]
# Out:
#           Date  State Country  Confirmed  Deaths  Recovered  Active  \
# 79  17-04-2021    NaN   India    1480073   33408     951166  495499
#
#     New cases  New deaths  New recovered
# 79      44457         637          33598

# %%
#sort the entire data wrt. to number of confirmed cases in ascending order?

# %%
df2.sort_values(["Confirmed"],ascending=True)
# Out:
#            Date  State                Country  Confirmed  Deaths  Recovered  \
# 183  30-07-2021    NaN         Western Sahara         10       1          8
# 75   13-04-2021    NaN               Holy See         12       0         12
# 68   06-04-2021    NaN              Greenland         14       0         13
# 140  17-06-2021    NaN  Saint Kitts and Nevis         17       0         15
# 49   18-03-2021    NaN               Dominica         18       0         18
# ..          ...    ...                    ...        ...     ...        ...
# 154  01-07-2021    NaN           South Africa     452529    7067     274925
# 138  15-06-2021    NaN                 Russia     816680   13334     602249
# 79   17-04-2021    NaN                  India    1480073   33408     951166
# 23   12-01-2021    NaN                 Brazil    2442375   87618    1846641
# 173  20-07-2021    NaN                     US    4290259  148011    1325804
#
#       Active  New cases  New deaths  New recovered
# ...

# %%
#sort the entire data wrt. to number of recovered cases in descencding order?

# %%
df2.sort_values(["Recovered"],ascending = False)
# Out:
#            Date  State      Country  Confirmed  Deaths  Recovered   Active  \
# 23   12-01-2021    NaN       Brazil    2442375   87618    1846641   508116
# 173  20-07-2021    NaN           US    4290259  148011    1325804  2816444
# 79   17-04-2021    NaN        India    1480073   33408     951166   495499
# 138  15-06-2021    NaN       Russia     816680   13334     602249   201097
# 35   04-03-2021    NaN        Chile     347923    9187     319954    18782
# ..          ...    ...          ...        ...     ...        ...      ...
# 32   01-03-2021    NaN       Canada     116458    8944          0   107514
# 168  15-07-2021    NaN  Timor-Leste         24       0          0       24
# 147  24-06-2021    NaN       Serbia      24141     543          0    23598
# 163  10-07-2021    NaN        Syria        674      40          0      634
# 161  08-07-2021    NaN       Sweden      79395    5700          0    73695
#
#      New cases  New deaths  New recovered
# ...
